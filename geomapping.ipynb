# %%
import pandas as pd
import gmplot
import geopy
import googlemaps
from datetime import datetime
import seaborn as sns

# %%
df = pd.read_csv('FastFoodRestaurants.csv')

# %%
df = df[df['province'] == 'MD']

# %%
df
# Out:
#                          address          city country  \
# 600           1060 Joppa Farm Rd         Joppa      US
# 973          8831 Chesapeake Ave   North Beach      US
# 1019                 925 York Rd        Towson      US
# 1034        40824 Merchants Lane   Leonardtown      US
# 1064         8320 Annapolis Road   Hyattsville      US
# ...                          ...           ...     ...
# 9916     10995 Owings Mills Blvd  Owings Mills      US
# 9936                6 Hyland Ave  Cockeysville      US
# 9966           1454 Whitehall Rd     Annapolis      US
# 9980  10300 Little Patuxent Pkwy      Columbia      US
# 9990            6910 Ritchie Hwy   Glen Burnie      US
#
#                                                    keys   latitude  longitude  \
# 600              us/md/joppa/1060joppafarmrd/-791445730  39.422525 -76.370389
# 973      us/md/northbeach/8831chesapeakeave/-2133364950  38.703740 -76.533240
# 1019                 us/md/towson/925yorkrd/-2061630068  39.408631 -76.608049
# 1034      us/md/leonardtown/40824merchantslane/93075755  38.307783 -76.663074
# 1064     us/md/hyattsville/8320annapolisroad/1241037051  38.957266 -76.871158
# ...                                                 ...        ...        ...
# 9916  us/md/owingsmills/10995owingsmillsblvd/-891525969  39.417171 -76.781379
# 9936           us/md/cockeysville/6hylandave/-345832572  39.496766 -76.651467
# 9966         us/md/annapolis/1454whitehallrd/-791445730  39.025693 -76.440942
# 9980   us/md/columbia/10300littlepatuxentpkwy/387392632  39.216640 -76.857860
# 9990         us/md/glenburnie/6910ritchiehwy/-791445730  39.186102 -76.612795
#
#                                        name postalCode province  \
# 600                                 Wendy's      21085       MD
# 973                            Dairy Freeze      20714       MD
# 1019                            Burger King      21204       MD
# 1034                                 Arby's      20650       MD
# 1064  Bojangles' Famous Chicken 'n Biscuits      20784       MD
# ...                                     ...        ...      ...
# 9916                                 Subway      21117       MD
# 9936                            Chick-fil-A      21030       MD
# 9966                                Wendy's      21409       MD
# 9980                            Sarku Japan      21044       MD
# 9990                                Wendy's      21061       MD
#
#                                                websites
# 600                               http://www.wendys.com
# 973                                                 NaN
# 1019                                  http://www.bk.com
# 1034                               http://www.arbys.com
# 1064                           http://www.bojangles.com
# ...                                                 ...
# 9916  http://subway.com/subwayroot/default.aspx,http...
# 9936  http://www.chick-fil-a.com/huntvalley,http://w...
# 9966                              http://www.wendys.com
# 9980    http://sarkujapan.com,http://www.sarkujapan.com
# 9990                              http://www.wendys.com
#
# [159 rows x 10 columns]

# %%
gmap = gmplot.GoogleMapPlotter(39.045753, -76.641273, 13)
gmap.apikey='AIzaSyB0nsUcmT7AURL7ivfL4t2dM-9sgBKxGD0'
gmap.draw("md.html")

# %%
lati = []
lngi = []
gmap = gmplot.GoogleMapPlotter(39.045753, -76.641273, 13)
gmap.apikey='AIzaSyB0nsUcmT7AURL7ivfL4t2dM-9sgBKxGD0'
gmaps = googlemaps.Client(key='AIzaSyB0nsUcmT7AURL7ivfL4t2dM-9sgBKxGD0')
for x in df['address']:
    geocode_result = gmaps.geocode(x)
    try:
        geom = geocode_result[0]['geometry']
        loc = geom['location']
        lat = loc['lat']
        lati.append(lat)
        lng = loc['lng']
        lngi.append(lng)
        gmap.scatter(lati, lngi, '#3B0B39', size=100, marker=False)
        gmap.draw("md.html")
    except IndexError:
        print('')
